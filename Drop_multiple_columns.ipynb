# %% [markdown]
# <a href="https://colab.research.google.com/github/VijayTaori/Python4DataScienceMachineLearningbootcamp/blob/master/Drop_multiple_columns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Create a dictionary with 4 keys
data = {
    'A':[1, 2, 3, 4, 5, 6],
    'B': [10, 20, 30, 40, 50, 60],
    'C': [100, 200, 300, 400, 500],
    'D':[1000, 2000, 3000, 4000, 5000, 6000],
}

# %%
df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-d1192c0ddc6b> in <module>
# ----> 1 df = pd.DataFrame(data)
#       2 df
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
# ...

# %%
# Create a dictionary with 4 keys
data = {
    'A':[1, 2, 3, 4, 5, 6],
    'B': [10, 20, 30, 40, 50, 60],
    'C': [100, 200, 300, 400, 500, 600],
    'D':[1000, 2000, 3000, 4000, 5000, 6000],
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    A   B    C     D
# 0  1  10  100  1000
# 1  2  20  200  2000
# 2  3  30  300  3000
# 3  4  40  400  4000
# 4  5  50  500  5000
# 5  6  60  600  6000

# %%
df.drop('A',axis=1)
# Out:
#     B    C     D
# 0  10  100  1000
# 1  20  200  2000
# 2  30  300  3000
# 3  40  400  4000
# 4  50  500  5000
# 5  60  600  6000

# %%
df.drop('A','B', axis=1)
# Out:
# <ipython-input-9-1e4a6e7aff74>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop('A','B', axis=1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-1e4a6e7aff74> in <module>
# ----> 1 df.drop('A','B', axis=1)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: drop() got multiple values for argument 'axis'

# %%
df.columns[0,1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-30b24acfefc4> in <module>
# ----> 1 df.columns[0,1]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4614             key = np.asarray(key, dtype=bool)
#    4615
# -> 4616         result = getitem(key)
#    4617         if not is_scalar(result):
#    4618             # error: Argument 1 to "ndim" has incompatible type "Union[ExtensionArray,
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
df.columns[[0,1]]
# Out:
# Index(['A', 'B'], dtype='object')

# %%
df.drop(['A','B'], axis=1)
# Out:
#      C     D
# 0  100  1000
# 1  200  2000
# 2  300  3000
# 3  400  4000
# 4  500  5000
# 5  600  6000

# %%
df.drop(df.columns[[0,1]],axis=1)
# Out:
#      C     D
# 0  100  1000
# 1  200  2000
# 2  300  3000
# 3  400  4000
# 4  500  5000
# 5  600  6000
